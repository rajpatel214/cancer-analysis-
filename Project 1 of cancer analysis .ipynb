# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"C:\Users\HP\Downloads\1 - Linear Regression Home Price Prediction & Analysis\2 - Clustering Cancer Lanalysis\ML Project - Clustering Cancer Database U16955459050.csv")

# %%
data.sample(5)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 270   8910721         B        14.29         16.82           90.30      632.6
# 442  90944601         B        13.78         15.79           88.37      585.9
# 4    84358402         M        20.29         14.34          135.10     1297.0
# 207    879830         M        17.01         20.26          109.70      904.3
# 503    915143         M        23.09         19.83          152.10     1682.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 270          0.06429           0.02675         0.00725             0.006250
# 442          0.08817           0.06718         0.01055             0.009937
# 4            0.10030           0.13280         0.19800             0.104300
# 207          0.08772           0.07304         0.06950             0.053900
# 503          0.09342           0.12750         0.16760             0.100300
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.isnull().sum() # here not any single column is null
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
data.shape
# Out:
# (569, 32)

# %%
#analysis majority of cancers

sns.countplot(data=data,x="diagnosis")
plt.xlabel("diagnosis analysis")
plt.ylabel("counts")
plt.title("Anlysis majority of cancer")
plt.show()

# %%
# it give ideas The average distance from the center of the tumor to its boundary
# analysis up to 60% patients has avg size of tumor 12 - 15 
sns.displot(data=data,x="radius_mean")
plt.xlabel("Avg Size Of The Tumor (radius)")
plt.ylabel("Counts")
plt.show()

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#The average distance from the center of the tumor to its boundary. It gives an idea of the size of the tumor.

# Create a figure for subplots
fig = plt.figure(figsize=(15, 5))  # Adjust size to fit three columns

# First subplot
plt.subplot(1, 3, 1)
sns.histplot(data=data, x="radius_mean", kde=True)  # Use histplot with optional KDE
plt.xlabel("Avg Size Of The Tumor (radius)")
plt.ylabel("Counts")
plt.title("Radius Mean Distribution")

# Second subplot
plt.subplot(1, 3, 2)
sns.histplot(data=data, x="radius_se", kde=True)
plt.xlabel("variation  Of The Tumor (radius)")
plt.ylabel("Counts")
plt.title("Radius SE Distribution")

# Third subplot
plt.subplot(1, 3, 3)
sns.histplot(data=data, x="radius_worst", kde=True)
plt.xlabel("Large Size Of The Tumor (radius)")
plt.ylabel("Counts")
plt.title("Radius Worst Distribution")

# Adjust layout
plt.tight_layout()

# Show the complete figure
plt.show()

# %%
#The boundary length of the tumor.

# Create a figure for subplots
fig = plt.figure(figsize=(15, 5))  # Adjust size to fit three columns

# First subplot
plt.subplot(1, 3, 1)
sns.histplot(data=data, x="perimeter_mean", kde=True)  # Use histplot with optional KDE
plt.xlabel("Avg Size Of The Tumor (perimeter)")
plt.ylabel("Counts")
plt.title("perimeter Mean Distribution")

# Second subplot
plt.subplot(1, 3, 2)
sns.histplot(data=data, x="perimeter_se", kde=True)
plt.xlabel("variation  Of The Tumor (perimeter)")
plt.ylabel("Counts")
plt.title("perimeter SE Distribution")

# Third subplot
plt.subplot(1, 3, 3)
sns.histplot(data=data, x="perimeter_worst", kde=True)
plt.xlabel("Large Size Of The Tumor (perimeter)")
plt.ylabel("Counts")
plt.title("perimeter Worst Distribution")

# Adjust layout
plt.tight_layout()

# Show the complete figure
plt.show()

# %%
# The area covered by the tumor.


fig = plt.figure(figsize=(15, 5))  # Adjust size to fit three columns

# First subplot
plt.subplot(1, 3, 1)
sns.histplot(data=data, x="area_mean", kde=True)  # Use histplot with optional KDE
plt.xlabel("Avg Size Of The Tumor (area)")
plt.ylabel("Counts")
plt.title("Area Mean Distribution")

# Second subplot
plt.subplot(1, 3, 2)
sns.histplot(data=data, x="area_se", kde=True)
plt.xlabel("variation  Of The Tumor (area)")
plt.ylabel("Counts")
plt.title("Area SE Distribution")

# Third subplot
plt.subplot(1, 3, 3)
sns.histplot(data=data, x="area_worst", kde=True)
plt.xlabel("Large Size Of The Tumor (area)")
plt.ylabel("Counts")
plt.title("Area Worst Distribution")

# Adjust layout
plt.tight_layout()

# Show the complete figure
plt.show()

# %%
# smooth or irregular the edges of the tumor
fig = plt.figure(figsize=(15, 5))  # Adjust size to fit three columns

# First subplot
plt.subplot(1, 3, 1)
sns.histplot(data=data, x="smoothness_mean", kde=True)  # Use histplot with optional KDE
plt.xlabel("Avg Size Of The Tumor (smoothness)")
plt.ylabel("Counts")
plt.title("smoothness Mean Distribution")

# Second subplot
plt.subplot(1, 3, 2)
sns.histplot(data=data, x="smoothness_se", kde=True)
plt.xlabel("variation  Of The Tumor (smoothness)")
plt.ylabel("Counts")
plt.title("smoothness SE Distribution")

# Third subplot
plt.subplot(1, 3, 3)
sns.histplot(data=data, x="smoothness_worst", kde=True)
plt.xlabel("Large Size Of The Tumor (smoothness)")
plt.ylabel("Counts")
plt.title("smoothness Worst Distribution")

# Adjust layout
plt.tight_layout()

# Show the complete figure
plt.show()

# %%
# how compact the tumor is
fig = plt.figure(figsize=(15, 5))  # Adjust size to fit three columns

# First subplot
plt.subplot(1, 3, 1)
sns.histplot(data=data, x="compactness_mean", kde=True)  # Use histplot with optional KDE
plt.xlabel("Avg Size Of The Tumor (compactness)")
plt.ylabel("Counts")
plt.title("compactness Mean Distribution")

# Second subplot
plt.subplot(1, 3, 2)
sns.histplot(data=data, x="compactness_se", kde=True)
plt.xlabel("variation  Of The Tumor (compactness)")
plt.ylabel("Counts")
plt.title("compactness SE Distribution")

# Third subplot
plt.subplot(1, 3, 3)
sns.histplot(data=data, x="compactness_worst", kde=True)
plt.xlabel("Large Size Of The Tumor (compactness)")
plt.ylabel("Counts")
plt.title("compactness Worst Distribution")

# Adjust layout
plt.tight_layout()

# Show the complete figure
plt.show()

# %%
# concave portions of the tumor boundary
fig = plt.figure(figsize=(15, 5))  # Adjust size to fit three columns

# First subplot
plt.subplot(1, 3, 1)
sns.histplot(data=data, x="concavity_mean", kde=True)  # Use histplot with optional KDE
plt.xlabel("Avg Size Of The Tumor (concavity)")
plt.ylabel("Counts")
plt.title("concavity Mean Distribution")

# Second subplot
plt.subplot(1, 3, 2)
sns.histplot(data=data, x="concavity_se", kde=True)
plt.xlabel("variation  Of The Tumor (concavity)")
plt.ylabel("Counts")
plt.title("concavity SE Distribution")

# Third subplot
plt.subplot(1, 3, 3)
sns.histplot(data=data, x="concavity_worst", kde=True)
plt.xlabel("Large Size Of The Tumor (concavity)")
plt.ylabel("Counts")
plt.title("concavity Worst Distribution")

# Adjust layout
plt.tight_layout()

# Show the complete figure
plt.show()

# %%
#Counts the number of concave points on the tumor boundary
fig = plt.figure(figsize=(15, 5))  # Adjust size to fit three columns

# First subplot
plt.subplot(1, 3, 1)
sns.histplot(data=data, x="concave points_mean", kde=True)  # Use histplot with optional KDE
plt.xlabel("Avg Size Of The Tumor (concave_points)")
plt.ylabel("Counts")
plt.title("concave_points Mean Distribution")

# Second subplot
plt.subplot(1, 3, 2)
sns.histplot(data=data, x="concave points_se", kde=True)
plt.xlabel("variation  Of The Tumor (concave_points)")
plt.ylabel("Counts")
plt.title("concave_points SE Distribution")

# Third subplot
plt.subplot(1, 3, 3)
sns.histplot(data=data, x="concave points_worst", kde=True)
plt.xlabel("Large Size Of The Tumor (concave_points)")
plt.ylabel("Counts")
plt.title("concave_points Worst Distribution")

# Adjust layout
plt.tight_layout()

# Show the complete figure
plt.show()

# %%
# Measures how symmetrical the tumor is
fig = plt.figure(figsize=(15, 5))  # Adjust size to fit three columns

# First subplot
plt.subplot(1, 3, 1)
sns.histplot(data=data, x="symmetry_mean", kde=True)  # Use histplot with optional KDE
plt.xlabel("Avg Size Of The Tumor (symmetry)")
plt.ylabel("Counts")
plt.title("symmetry Mean Distribution")

# Second subplot
plt.subplot(1, 3, 2)
sns.histplot(data=data, x="symmetry_se", kde=True)
plt.xlabel("variation  Of The Tumor (symmetry)")
plt.ylabel("Counts")
plt.title("symmetry variation Distribution")

# Third subplot
plt.subplot(1, 3, 3)
sns.histplot(data=data, x="symmetry_worst", kde=True)
plt.xlabel("Large Size Of The Tumor (symmetry)")
plt.ylabel("Counts")
plt.title("symmetry Worst Distribution")

# Adjust layout
plt.tight_layout()

# Show the complete figure
plt.show()

# %%
# Captures the complexity of the tumor boundary
fig = plt.figure(figsize=(15, 5))  # Adjust size to fit three columns

# First subplot
plt.subplot(1, 3, 1)
sns.histplot(data=data, x="fractal_dimension_mean", kde=True)  # Use histplot with optional KDE
plt.xlabel("Avg Size Of The Tumor (fractal_dimension)")
plt.ylabel("Counts")
plt.title("fractal_dimension Mean Distribution")

# Second subplot
plt.subplot(1, 3, 2)
sns.histplot(data=data, x="fractal_dimension_se", kde=True)
plt.xlabel("variation  Of The Tumor (symmetry)")
plt.ylabel("Counts")
plt.title("fractal_dimension variation Distribution")

# Third subplot
plt.subplot(1, 3, 3)
sns.histplot(data=data, x="fractal_dimension_worst", kde=True)
plt.xlabel("Large Size Of The Tumor (fractal_dimension)")
plt.ylabel("Counts")
plt.title("fractal_dimension Worst Distribution")

# Adjust layout
plt.tight_layout()

# Show the complete figure
plt.show()

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
data.drop("id",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[354], line 1
# ----> 1 data.drop("id",axis=1,inplace=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
data["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
# encoding
data["diagnosis"]=data["diagnosis"].replace({"B":0,"M":1})

# %% [markdown]
# # scaling

# %%
#scaling 
from sklearn.preprocessing import RobustScaler

r=RobustScaler()

data_scaling=r.fit_transform(data)

# %% [markdown]
# # eblow method for find cluster number

# %%
# using elbow method get best cluster number 
intertia=[]

for i in range(1,11):
    model=KMeans(n_clusters=i)
    model.fit(data_scaling)
    intertia.append(model.inertia_)



plt.plot(range(1,11),intertia,marker="o")

# %% [markdown]
# # Kmeans

# %%
# apply Kmeans
from sklearn.cluster import KMeans

k=KMeans(n_clusters=2)

k.fit(data_scaling)

data['Cluster']=k.predict(data_scaling)

# %%
plt.scatter(data['radius_mean'], data['texture_mean'], c=data['Cluster'], cmap='viridis')
plt.xlabel('Radius Mean')
plt.ylabel('Texture Mean')
plt.title('Cluster Distribution')
plt.show()

# %%
# # Use PCA to reduce the data to 2D
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(data_scaling)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=data['Cluster'], cmap='viridis')

# %%
#check point fits within its cluster
from sklearn.metrics import silhouette_score
silhouette_score(data,data['Cluster'])
# Out:
# 0.5392255550010309

# %% [markdown]
# # hierarchy

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

import scipy.cluster.hierarchy as shc

# %%
shc.dendrogram(shc.linkage(data,method="ward"))
plt.show()

# %% [markdown]
# # AgglomerativeClustering

# %%
#using AgglomerativeClustering

from sklearn.cluster import AgglomerativeClustering

a=AgglomerativeClustering(n_clusters=2,linkage='ward')

data['cluster_label_Agglomerative']=a.fit_predict(data_scaling)

# %%
from sklearn.metrics import silhouette_score

silhouette_score(data,data["cluster_label_Agglomerative"])
# Out:
# 0.4917745697489997

# %%
#Plot the Cluster Labels
plt.scatter(data['radius_mean'], data['texture_mean'], c=data['cluster_label_Agglomerative'], cmap='viridis')
plt.xlabel('Radius Mean')
plt.ylabel('Texture Mean')
plt.title('Cluster Distribution')
plt.show()

# %%
data.drop("Cluster",axis=1,inplace=True)

# %%
data
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
x=data.drop("diagnosis",axis=1)

y=data["diagnosis"]

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler

r=StandardScaler()

train_sacling=r.fit_transform(x_train)

test_sacling=r.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score,KFold

list=[LogisticRegression,DecisionTreeClassifier,RandomForestClassifier,SVC,KNeighborsClassifier]

k=KFold(n_splits=5)

#without scaling data 
for i in list:
    model=i()
    print(i)
    print(cross_val_score(model,x_train,y_train,cv=k).mean())
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# 0.945054945054945
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# 0.9208791208791208
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# 0.9604395604395604
# <class 'sklearn.svm._classes.SVC'>
# 0.9032967032967033
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# 0.9362637362637363

# %%
#with scaling data 

for i in list:
    model=i()
    print(i)
    print(cross_val_score(model,train_sacling,y_train,cv=k).mean())
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# 0.9714285714285715
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# 0.9054945054945055
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# 0.956043956043956
# <class 'sklearn.svm._classes.SVC'>
# 0.9670329670329672
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# 0.9582417582417582

# %% [markdown]
# # LogisticRegression

# %%
#LogisticRegression  high score give from all those model
lr=LogisticRegression(C=50,random_state=10)

lr.fit(train_sacling,y_train)

lr.score(train_sacling,y_train)

lr.score(test_sacling,y_test)
# Out:
# 0.9824561403508771

# %% [markdown]
# # RandomForestClassifier

# %%
r=RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=100,
                       n_estimators=200, random_state=30)

r.fit(train_sacling,y_train)

r.score(train_sacling,y_train)

r.score(test_sacling,y_test)
# Out:
# 0.956140350877193

# %% [markdown]
# #  Hypertuning Parameter

# %%
#using RandomizedSearchCV

from sklearn.model_selection import RandomizedSearchCV

n_estimators=[200,300,400,500]
max_depth=[10,20,30,40]
min_samples_split=[100,200,300,400]
bootstrap=[True,False]
random_state=[20,30,40,50]


dic={
    "n_estimators":[200,300,400,500],
    "max_depth":[5,10,20,30,40],
    "min_samples_split":[50,100,200,300,400],
    "bootstrap":[True,False],
    "random_state":[20,30,40,50]
}

random=RandomizedSearchCV(r,param_distributions=dic,cv=k,verbose=0)

# %%
random.fit(train_sacling,y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=RandomForestClassifier(bootstrap=False,
#                                                     max_depth=30,
#                                                     min_samples_split=100,
#                                                     n_estimators=300,
#                                                     random_state=40),
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [5, 10, 20, 30, 40],
#                                         'min_samples_split': [50, 100, 200, 300,
#                                                               400],
#                                         'n_estimators': [200, 300, 400, 500],
#                                         'random_state': [20, 30, 40, 50]})

# %%
random.best_estimator_  #get best hyperparameters
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=5, min_samples_split=100,
#                        n_estimators=200, random_state=30)

# %% [markdown]
# # svc

# %%
s=SVC()

s.fit(train_sacling,y_train)

s.score(train_sacling,y_train)

s.score(test_sacling,y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# # Best Algorithom Is LogisticRegression
